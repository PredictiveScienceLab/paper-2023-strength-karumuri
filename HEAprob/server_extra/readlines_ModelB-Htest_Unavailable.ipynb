"ModelB-Htest_Unavailable_results/57-seed/57-output.txt",
"ModelB-Htest_Unavailable_results/58-seed/58-output.txt",
"ModelB-Htest_Unavailable_results/59-seed/59-output.txt",
"ModelB-Htest_Unavailable_results/60-seed/60-output.txt",
"ModelB-Htest_Unavailable_results/61-seed/61-output.txt",
"ModelB-Htest_Unavailable_results/62-seed/62-output.txt",
"ModelB-Htest_Unavailable_results/63-seed/63-output.txt",
"ModelB-Htest_Unavailable_results/64-seed/64-output.txt",
"ModelB-Htest_Unavailable_results/65-seed/65-output.txt",
"ModelB-Htest_Unavailable_results/66-seed/66-output.txt",
"ModelB-Htest_Unavailable_results/67-seed/67-output.txt",
"ModelB-Htest_Unavailable_results/68-seed/68-output.txt",
"ModelB-Htest_Unavailable_results/69-seed/69-output.txt",
"ModelB-Htest_Unavailable_results/70-seed/70-output.txt",
"ModelB-Htest_Unavailable_results/71-seed/71-output.txt",
"ModelB-Htest_Unavailable_results/72-seed/72-output.txt",
"ModelB-Htest_Unavailable_results/73-seed/73-output.txt",
"ModelB-Htest_Unavailable_results/74-seed/74-output.txt",
"ModelB-Htest_Unavailable_results/75-seed/75-output.txt",
"ModelB-Htest_Unavailable_results/76-seed/76-output.txt",
"ModelB-Htest_Unavailable_results/77-seed/77-output.txt",
"ModelB-Htest_Unavailable_results/78-seed/78-output.txt",
"ModelB-Htest_Unavailable_results/79-seed/79-output.txt",
"ModelB-Htest_Unavailable_results/80-seed/80-output.txt",
"ModelB-Htest_Unavailable_results/81-seed/81-output.txt",
"ModelB-Htest_Unavailable_results/82-seed/82-output.txt",
"ModelB-Htest_Unavailable_results/83-seed/83-output.txt",
"ModelB-Htest_Unavailable_results/84-seed/84-output.txt",
"ModelB-Htest_Unavailable_results/85-seed/85-output.txt",
"ModelB-Htest_Unavailable_results/86-seed/86-output.txt",
"ModelB-Htest_Unavailable_results/87-seed/87-output.txt",
"ModelB-Htest_Unavailable_results/88-seed/88-output.txt",
"ModelB-Htest_Unavailable_results/89-seed/89-output.txt",
"ModelB-Htest_Unavailable_results/90-seed/90-output.txt",
"ModelB-Htest_Unavailable_results/91-seed/91-output.txt",
"ModelB-Htest_Unavailable_results/92-seed/92-output.txt",
"ModelB-Htest_Unavailable_results/93-seed/93-output.txt",
"ModelB-Htest_Unavailable_results/94-seed/94-output.txt",
"ModelB-Htest_Unavailable_results/95-seed/95-output.txt",
"ModelB-Htest_Unavailable_results/96-seed/96-output.txt",
"ModelB-Htest_Unavailable_results/97-seed/97-output.txt",
"ModelB-Htest_Unavailable_results/98-seed/98-output.txt",
"ModelB-Htest_Unavailable_results/99-seed/99-output.txt",
"ModelB-Htest_Unavailable_results/100-seed/100-output.txt"]

# %%
import os

# Set path to the folder: (replace with your own filepath!):
folder = os.getcwd()

objective_list = []
for i in range(len(filename)):
    
    # Generate full filepath by combining the folder and filename
    fp = os.path.join(folder, filename[i])
    
    f1 = open(fp, "r")
    last_line = f1.readlines()[-2]
    print (last_line)
    
    s_array = last_line.split('Strength MAE test:')
    objective_list.append(s_array[1])
    
    f1.close()

Strength_MAE_test_list = list(map(float, objective_list))
print(Strength_MAE_test_list)
# Out:
# Strength MAE test: 376.1612892189534
#
# Strength MAE test: 380.39242657627887
#
# Strength MAE test: 371.58189921230365
#
# Strength MAE test: 301.9116097100555
#
# Strength MAE test: 293.95272028351087
#
# Strength MAE test: 337.9971487062437
#
# Strength MAE test: 321.08978627721126
#
# Strength MAE test: 289.4968636464089
#
# Strength MAE test: 339.2280049017819
#
# Strength MAE test: 349.3519461337471
#
# Strength MAE test: 271.663464711609
#
# Strength MAE test: 480.8971117339228
#
# Strength MAE test: 313.6375230989005
#
# Strength MAE test: 339.5397809609085
#
# Strength MAE test: 317.0142394351145
#
# Strength MAE test: 373.08898273742994
#
# Strength MAE test: 283.53976880104153
#
# Strength MAE test: 369.01517908174594
#
# Strength MAE test: 387.584932843447
#
# Strength MAE test: 363.5142682416052
#
# Strength MAE test: 285.6976293963032
#
# Strength MAE test: 374.0627847980907
#
# Strength MAE test: 350.91474735198597
#
# Strength MAE test: 331.71767264812524
#
# ...

# %%
import os

# Set path to the folder: (replace with your own filepath!):
folder = os.getcwd()

objective_list = []
for i in range(len(filename)):
    
    # Generate full filepath by combining the folder and filename
    fp = os.path.join(folder, filename[i])
    
    f1 = open(fp, "r")
    last_line = f1.readlines()[-1]
    print (last_line)
    
    s_array = last_line.split('Strength KS test:')
    objective_list.append(s_array[1])
    
    f1.close()

Strength_KS_test_list = list(map(float, objective_list))
print(Strength_KS_test_list)
# Out:
# Strength KS test: 0.16749999999999998
#
# Strength KS test: 0.15300000000000002
#
# Strength KS test: 0.118
#
# Strength KS test: 0.1205
#
# Strength KS test: 0.17474999999999996
#
# Strength KS test: 0.11924999999999997
#
# Strength KS test: 0.14625
#
# Strength KS test: 0.16149999999999998
#
# Strength KS test: 0.26425
#
# Strength KS test: 0.11549999999999999
#
# Strength KS test: 0.11175000000000002
#
# Strength KS test: 0.3075
#
# Strength KS test: 0.241
#
# Strength KS test: 0.09675
#
# Strength KS test: 0.15349999999999997
#
# Strength KS test: 0.21799999999999997
#
# Strength KS test: 0.176
#
# Strength KS test: 0.13524999999999998
#
# Strength KS test: 0.096
#
# Strength KS test: 0.22299999999999998
#
# Strength KS test: 0.14275
#
# Strength KS test: 0.13224999999999998
#
# Strength KS test: 0.12675000000000003
#
# Strength KS test: 0.245
#
# Strength KS test: 0.22599999999999998
#
# Strength KS test: 0.177
#
# Strength KS test: 0.23375
#
# Strength KS test: 0.09625
#
# ...

# %%
print(Strength_MAE_test_list)
print(Strength_KS_test_list)

print('######CLT statistic estimates###########')
import statistics
import numpy as np
print(statistics.mean(Strength_MAE_test_list))
print(statistics.mean(Strength_KS_test_list))
print(statistics.stdev(Strength_MAE_test_list)/np.sqrt(len(Strength_MAE_test_list)))
print(statistics.stdev(Strength_KS_test_list)/np.sqrt(len(Strength_KS_test_list)))
# Out:
# [376.1612892189534, 380.39242657627887, 371.58189921230365, 301.9116097100555, 293.95272028351087, 337.9971487062437, 321.08978627721126, 289.4968636464089, 339.2280049017819, 349.3519461337471, 271.663464711609, 480.8971117339228, 313.6375230989005, 339.5397809609085, 317.0142394351145, 373.08898273742994, 283.53976880104153, 369.01517908174594, 387.584932843447, 363.5142682416052, 285.6976293963032, 374.0627847980907, 350.91474735198597, 331.71767264812524, 264.29391681942565, 391.43225382223295, 318.7318878219414, 292.21099952180873, 328.19170643225317, 310.34988969257194, 278.7272276159987, 380.42013906336956, 370.06369934733846, 297.7531450561376, 293.6063871208402, 290.7595242831029, 321.8036017058966, 318.46713430300076, 304.10555204444927, 370.3553837791628, 386.5409924569875, 282.58454158698135, 325.928647954706, 301.53242720150195, 322.6234026498947, 388.2622829330583, 247.66462878021738, 404.49922134802193, 324.7027580965175, 365.9878226522427, 303.5108313612013, 236.26474
# ...
