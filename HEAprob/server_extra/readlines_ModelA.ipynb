"ModelA_results/68-seed/68-output.txt",
"ModelA_results/69-seed/69-output.txt",
"ModelA_results/70-seed/70-output.txt",
"ModelA_results/71-seed/71-output.txt",
"ModelA_results/72-seed/72-output.txt",
"ModelA_results/73-seed/73-output.txt",
"ModelA_results/74-seed/74-output.txt",
"ModelA_results/75-seed/75-output.txt",
"ModelA_results/76-seed/76-output.txt",
"ModelA_results/77-seed/77-output.txt",
"ModelA_results/78-seed/78-output.txt",
"ModelA_results/79-seed/79-output.txt",
"ModelA_results/80-seed/80-output.txt",
"ModelA_results/81-seed/81-output.txt",
"ModelA_results/82-seed/82-output.txt",
"ModelA_results/83-seed/83-output.txt",
"ModelA_results/84-seed/84-output.txt",
"ModelA_results/85-seed/85-output.txt",
"ModelA_results/86-seed/86-output.txt",
"ModelA_results/87-seed/87-output.txt",
"ModelA_results/88-seed/88-output.txt",
"ModelA_results/89-seed/89-output.txt",
"ModelA_results/90-seed/90-output.txt",
"ModelA_results/91-seed/91-output.txt",
"ModelA_results/92-seed/92-output.txt",
"ModelA_results/93-seed/93-output.txt",
"ModelA_results/94-seed/94-output.txt",
"ModelA_results/95-seed/95-output.txt",
"ModelA_results/96-seed/96-output.txt",
"ModelA_results/97-seed/97-output.txt",
"ModelA_results/98-seed/98-output.txt",
"ModelA_results/99-seed/99-output.txt",
"ModelA_results/100-seed/100-output.txt"]

# %%
import os

# Set path to the folder: (replace with your own filepath!):
folder = os.getcwd()

objective_list = []
for i in range(len(filename)):
    
    # Generate full filepath by combining the folder and filename
    fp = os.path.join(folder, filename[i])
    
    f1 = open(fp, "r")
    last_line = f1.readlines()[-2]
    print (last_line)
    
    s_array = last_line.split('Strength MAE test:')
    objective_list.append(s_array[1])
    
    f1.close()

Strength_MAE_test_list = list(map(float, objective_list))
print(Strength_MAE_test_list)
# Out:
# Strength MAE test: 296.13009282537587
#
# Strength MAE test: 328.762326603205
#
# Strength MAE test: 239.4712623876447
#
# Strength MAE test: 235.48220345027846
#
# Strength MAE test: 214.6618191260813
#
# Strength MAE test: 296.6935414566006
#
# Strength MAE test: 296.03533311839703
#
# Strength MAE test: 205.60916713513154
#
# Strength MAE test: 383.02023691209115
#
# Strength MAE test: 225.2422320139052
#
# Strength MAE test: 250.92994875677664
#
# Strength MAE test: 368.91398924854127
#
# Strength MAE test: 203.5138156247998
#
# Strength MAE test: 291.6907938747101
#
# Strength MAE test: 269.62628593418947
#
# Strength MAE test: 210.82407423343568
#
# Strength MAE test: 215.1963950866575
#
# Strength MAE test: 278.1921602484926
#
# Strength MAE test: 228.1916961308346
#
# Strength MAE test: 288.66850671488993
#
# Strength MAE test: 212.13906079923285
#
# Strength MAE test: 273.53657350477863
#
# Strength MAE test: 288.54515348737925
#
# Strength MAE test: 243.99041748974236
#
# ...

# %%
import os

# Set path to the folder: (replace with your own filepath!):
folder = os.getcwd()

objective_list = []
for i in range(len(filename)):
    
    # Generate full filepath by combining the folder and filename
    fp = os.path.join(folder, filename[i])
    
    f1 = open(fp, "r")
    last_line = f1.readlines()[-1]
    print (last_line)
    
    s_array = last_line.split('Strength KS test:')
    objective_list.append(s_array[1])
    
    f1.close()

Strength_KS_test_list = list(map(float, objective_list))
print(Strength_KS_test_list)
# Out:
# Strength KS test: 0.15574999999999994
#
# Strength KS test: 0.23175
#
# Strength KS test: 0.126
#
# Strength KS test: 0.26375
#
# Strength KS test: 0.10349999999999998
#
# Strength KS test: 0.20225000000000004
#
# Strength KS test: 0.18325000000000002
#
# Strength KS test: 0.15674999999999994
#
# Strength KS test: 0.357
#
# Strength KS test: 0.12375000000000003
#
# Strength KS test: 0.10799999999999998
#
# Strength KS test: 0.26925
#
# Strength KS test: 0.14550000000000002
#
# Strength KS test: 0.14475
#
# Strength KS test: 0.17625000000000002
#
# Strength KS test: 0.1815
#
# Strength KS test: 0.202
#
# Strength KS test: 0.14550000000000002
#
# Strength KS test: 0.16325
#
# Strength KS test: 0.20124999999999998
#
# Strength KS test: 0.12824999999999998
#
# Strength KS test: 0.15399999999999997
#
# Strength KS test: 0.11924999999999997
#
# Strength KS test: 0.247
#
# Strength KS test: 0.23275
#
# Strength KS test: 0.13425
#
# Strength KS test: 0.24324999999999997
#
# ...

# %%
print(Strength_MAE_test_list)
print(Strength_KS_test_list)

print('######CLT statistic estimates###########')
import statistics
import numpy as np
print(statistics.mean(Strength_MAE_test_list))
print(statistics.mean(Strength_KS_test_list))
print(statistics.stdev(Strength_MAE_test_list)/np.sqrt(len(Strength_MAE_test_list)))
print(statistics.stdev(Strength_KS_test_list)/np.sqrt(len(Strength_KS_test_list)))
# Out:
# [296.13009282537587, 328.762326603205, 239.4712623876447, 235.48220345027846, 214.6618191260813, 296.6935414566006, 296.03533311839703, 205.60916713513154, 383.02023691209115, 225.2422320139052, 250.92994875677664, 368.91398924854127, 203.5138156247998, 291.6907938747101, 269.62628593418947, 210.82407423343568, 215.1963950866575, 278.1921602484926, 228.1916961308346, 288.66850671488993, 212.13906079923285, 273.53657350477863, 288.54515348737925, 243.99041748974236, 236.37924521381723, 274.35743058172983, 244.13380458359768, 180.16364415247165, 238.91019339906356, 185.79751922353918, 312.93463948146064, 259.6077244611561, 277.592691462198, 284.818894623818, 258.9264720727829, 197.3156871461245, 251.44473391853396, 225.69546186206347, 156.5811106019903, 227.01402876575864, 265.30206622260476, 249.95219927550326, 333.515717046833, 204.68630997914204, 210.18349086503474, 242.00353472185418, 154.87756211337268, 331.9815093744663, 259.36339648481464, 231.50645343496757, 272.96913797789506,
# ...

# %%
1.96*(4.8633361979000345)
# Out:
# 9.532138947884068

# %%
1.96*(0.005733635579374634)
# Out:
# 0.011237925735574283
